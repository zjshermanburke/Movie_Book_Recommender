# %%
from DatabaseConnection import *

# %%
# Define Constants
# Database connection information
DATABASE = "movie_book_database"
USER = "postgres"
PASSWORD = "password"
HOST = "localhost"
PORT = 5432

# Table to pull data from
TABLE = "movie_collection"

# %%
database = DatabaseConnection(DATABASE, USER, PASSWORD, TABLE)
df = database.get_data()

# %%
df
# Out:
#        title  times_watched  user_rating mpa_rating
# 0     Apples              0            5      PG-13
# 1     Django              3            5          R
# 2  Star Wars              3            4      PG-13
# 3  Zoolander              1            5          M

# %%
cursor = set_connection(DATABASE, USER, PASSWORD)
df = get_data(TABLE, cursor)

# %%
df
# Out:
#        title  times_watched  user_rating mpa_rating
# 0     Apples              0            5      PG-13
# 1     Django              3            5          R
# 2  Star Wars              3            4      PG-13
# 3  Zoolander              1            5          M

# %%
import pandas as pd

df = pd.read_csv('../Data/title.basics.tsv.gz', compression='gzip', sep='\t', low_memory=False)

# %%
print(df.shape)
df.head(100)
# Out:
# (11597904, 9)
#        tconst titleType                   primaryTitle  \
# 0   tt0000001     short                     Carmencita
# 1   tt0000002     short         Le clown et ses chiens
# 2   tt0000003     short                   Poor Pierrot
# 3   tt0000004     short                    Un bon bock
# 4   tt0000005     short               Blacksmith Scene
# ..        ...       ...                            ...
# 95  tt0000097     short   Place de l'Opéra, First View
# 96  tt0000098     short  Place de l'Opéra, Second View
# 97  tt0000099     short           Place de la Bastille
# 98  tt0000100     short           Place de la Concorde
# 99  tt0000101     short      Place du théâtre français
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                     Carmencita       0      1894      \N              1
# 1         Le clown et ses chiens       0      1892      \N              5
# ...

# %%
filtered_df = df[df['titleType'] == 'movie']
filtered_df = filtered_df.drop('endYear', axis=1)
filtered_df = filtered_df[filtered_df['genres'] != '\\N']
print(filtered_df.shape)
filtered_df.head(100)
# Out:
# (635452, 8)
#          tconst titleType                               primaryTitle  \
# 8     tt0000009     movie                                 Miss Jerry
# 144   tt0000147     movie              The Corbett-Fitzsimmons Fight
# 570   tt0000574     movie                The Story of the Kelly Gang
# 587   tt0000591     movie                           The Prodigal Son
# 610   tt0000615     movie                         Robbery Under Arms
# ...         ...       ...                                        ...
# 2795  tt0002822     movie                 What 80 Million Women Want
# 2805  tt0002832     movie                                 Evangeline
# 2806  tt0002833     movie                                   Evinrude
# 2817  tt0002844     movie  Fantômas: In the Shadow of the Guillotine
# 2830  tt0002857     movie           Uma Ferra em Salvaterra de Magos
#
#                                originalTitle isAdult startYear runtimeMinutes  \
# ...
